# %%
# !pip install kagglehub

# %%
import pandas as pd
import kagglehub

# Download latest version
path = kagglehub.dataset_download("shivd24coder/usa-vehicle-insights-2021")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Raksha\.cache\kagglehub\datasets\shivd24coder\usa-vehicle-insights-2021\versions\1

# %%
import pandas as pd
import os

path = r"C:\Users\Raksha\.cache\kagglehub\datasets\shivd24coder\usa-vehicle-insights-2021\versions\1"

print(os.listdir(path))
# Out:
# ['vius-data-dictionary-for-downloadable-tables.xlsx', 'VIUSC2021.VIUS214A-2024-01-04T181524.csv', 'vius_2021_puf.csv']

# %%
df = pd.read_csv(os.path.join(path,"vius_2021_puf.csv"))

# %%
df.head()
# Out:
#    ID  TABWEIGHT REGSTATE ACQUIREYEAR  ACQUISITION AVGWEIGHT BRAKES BTYPE  \
# 0   1       38.5       MT          11            2        14      3     X
# 1   2      197.4       NC           Z            2        12      3     X
# 2   3     1709.0       SD         21P            2        01      X    04
# 3   4       52.0       ID          03            2         X      3     X
# 4   5      286.5       MO           Z            2        01      1    13
#
#    BUSRELATED CAB  ... TE_SIDESKIRTS  TE_UCAERODEV  TOTLENGTH  TOWCAPACITY  \
# 0           1   X  ...             2             2         14            6
# 1           1   X  ...             2             2         12            4
# 2           2   X  ...             X             X         01            1
# 3           3   X  ...             X             X          X            3
# 4           2   1  ...             X             X         02            6
#
# ...

# %%
df.shape
# Out:
# (67952, 168)

# %%
df.columns
# Out:
# Index(['ID', 'TABWEIGHT', 'REGSTATE', 'ACQUIREYEAR', 'ACQUISITION',
#        'AVGWEIGHT', 'BRAKES', 'BTYPE', 'BUSRELATED', 'CAB',
#        ...
#        'TE_SIDESKIRTS', 'TE_UCAERODEV', 'TOTLENGTH', 'TOWCAPACITY',
#        'TRANSMISSION', 'TRIPOFFROAD', 'TRUCKLOADPCT', 'TTYPE', 'VEHTYPE',
#        'WEIGHOUTPCT'],
#       dtype='object', length=168)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67952 entries, 0 to 67951
# Columns: 168 entries, ID to WEIGHOUTPCT
# dtypes: float64(1), int64(60), object(107)
# memory usage: 87.1+ MB

# %%
df.describe()
# Out:
#                  ID      TABWEIGHT   ACQUISITION    BUSRELATED     CABHEIGHT  \
# count  67952.000000   67952.000000  67952.000000  67952.000000  67952.000000
# mean   33976.500000    2646.248118      1.611608      1.611711      2.933129
# std    19616.197083    8401.819642      0.537556      0.821181      1.894419
# min        1.000000       2.100000      1.000000      1.000000      1.000000
# 25%    16988.750000      64.600000      1.000000      1.000000      1.000000
# 50%    33976.500000     153.200000      2.000000      1.000000      2.000000
# 75%    50964.250000     552.200000      2.000000      2.000000      4.000000
# max    67952.000000  271726.900000      3.000000      4.000000      6.000000
#
#        CI_AUTOEBRAKE  CI_AUTOESTEER  CI_RAUTOEBRAKE  CW_BLINDSPOT  \
# count   67952.000000   67952.000000    67952.000000  67952.000000
# mean        1.793148       1.851763        1.841756      1.771942
# std         0.550846       0.515393        0.522082      0.572030
# ...

# %%
df.isnull().sum()
# Out:
# ID                 0
# TABWEIGHT          0
# REGSTATE           0
# ACQUIREYEAR        0
# ACQUISITION        0
#                 ...
# TRIPOFFROAD     5553
# TRUCKLOADPCT    1770
# TTYPE              0
# VEHTYPE            0
# WEIGHOUTPCT      789
# Length: 168, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['ID', 'TABWEIGHT', 'ACQUISITION', 'BUSRELATED', 'CABHEIGHT',
#        'CI_AUTOEBRAKE', 'CI_AUTOESTEER', 'CI_RAUTOEBRAKE', 'CW_BLINDSPOT',
#        'CW_FWDCOLL', 'CW_LANEDEPART', 'CW_PARKOBST', 'CW_RCROSSTRAF',
#        'DC_ACTDRIVASST', 'DC_ADAPCRUISE', 'DC_LANEASST', 'DC_PLATOON',
#        'DC_VTVCOMM', 'DRIVEAXLES', 'FE_AEROBUMP', 'FE_AEROHOOD',
#        'FE_AEROMIRROR', 'FE_AUTOENGOFF', 'FE_AUTOTIREINF', 'FE_HYBDRIVENP',
#        'FE_HYBDRIVEPL', 'FE_IDLEREDUCE', 'FE_LRRTIRES', 'FTYPE', 'MILESANNL',
#        'MONTHOPERATE', 'OD_AHIGHBEAM', 'OD_BACKUPCAM', 'OD_DRIVERMON',
#        'OD_HUD', 'OD_NIGHTVIS', 'OD_SVCAM', 'OF_AIRCOMPRESS', 'OF_AIRSPRING',
#        'OF_CRANE', 'OF_HOIST', 'OF_LIFTGATE', 'OF_PARTITION', 'OF_POWTAKEOFF',
#        'OF_TELEMATICS', 'OF_TOOLBOX', 'OF_WINCH', 'PA_APARKASST',
#        'PA_REMOTEPARK', 'REARAXLETIRES', 'RGROUP', 'ST_ABS', 'ST_AIRBAG',
#        'ST_CRUISE', 'ST_DRIVERCAM', 'ST_GPS', 'ST_GPSNAV', 'ST_INTERNET',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x=df['TRANSMISSION'])

plt.show()

# %%
sns.countplot(x=df['TRANSMISSION'])

plt.xticks(rotation=90)

plt.show()

# %%
df['TRANSMISSION'].value_counts()
# Out:
# TRANSMISSION
# 1    41046
# 2    22968
# 5     2982
# 3      934
# 4       22
# Name: count, dtype: int64

# %%
sns.histplot(df['MILESANNL'])
plt.show()
sns.histplot(df['MILESANNL'],kde=True)
plt.show()

# %%
sns.boxplot(x=df['MILESANNL'])

plt.show()

# %%
sns.violinplot(x=df['MILESANNL'])

plt.show()

# %%
sns.countplot(x=df['TRANSMISSION'])

plt.xticks(rotation=90)

plt.show()

# %%
print(os.getcwd())
# Out:
# C:\Users\Raksha
